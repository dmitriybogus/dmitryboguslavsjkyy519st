# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

plt.subplot(2,1,1)
x = np.linspace(0,8)
plt.plot(x,np.sin(x))
plt.title("graph")
plt.subplot(2,1,2)
plt.plot(x,np.cos(x))
