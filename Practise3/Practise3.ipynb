# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis
from scipy.stats import skew
# %matplotlib inline

a, b = 0, 1

print("Размер выборки = 1000")
x_uniform = np.random.uniform(a, b, 1000)

print("Среднее значение : ", np.mean(x_uniform))

print("Дисперсия : ", np.var(x_uniform))

print("Коэффициент асимметрии : ", skew(x_uniform)) 

print("Коэффициент эксцесса : ", kurtosis(x_uniform))

print("Размер выборки = 10000")
x_uniform = np.random.uniform(a, b, 10000)

print("Среднее значение : ", np.mean(x_uniform))

print("Дисперсия : ", np.var(x_uniform))

print("Коэффициент асимметрии : ", skew(x_uniform)) 

print("Коэффициент эксцесса : ", kurtosis(x_uniform))

print("Размер выборки = 100000")
x_uniform = np.random.uniform(a, b, 100000)

print("Среднее значение : ", np.mean(x_uniform))

print("Дисперсия : ", np.var(x_uniform))

print("Коэффициент асимметрии : ", skew(x_uniform)) 

print("Коэффициент эксцесса : ", kurtosis(x_uniform))

plt.figure(figsize=(7, 4.5))

plt.hist(x_uniform, 10, edgecolor='k')

plt.figure(figsize=(7, 4.5))

count, bins, ignored = plt.hist(x_uniform, 10, edgecolor='k', density=True)
plt.plot(bins, np.ones_like(bins) / (b - a), linewidth=2, color='r')
plt.show()
# Out:
# Размер выборки = 1000
# Среднее значение :  0.4887745014597014
# Дисперсия :  0.08061673953576581
# Коэффициент асимметрии :  0.06459778330707532
# Коэффициент эксцесса :  -1.161615895466341
# Размер выборки = 10000
# Среднее значение :  0.49648334783995896
# Дисперсия :  0.08347942211530471
# Коэффициент асимметрии :  0.018979896068559175
# Коэффициент эксцесса :  -1.202705286197685
# Размер выборки = 100000
# Среднее значение :  0.4999899783639757
# Дисперсия :  0.08331805116919805
# Коэффициент асимметрии :  1.3905953783487287e-05
# Коэффициент эксцесса :  -1.197166435231775

# %%
mu, sigma = 0, 1

print("Размер выборки = 1000")
x_n = np.random.normal(mu, sigma, 1000)

print("Среднее значение : ", np.mean(x_n))

print("Дисперсия : ", np.var(x_n))

print("Коэффициент асимметрии : ", skew(x_n)) 

print("Коэффициент эксцесса : ", kurtosis(x_n))

print("Размер выборки = 10000")
x_n = np.random.normal(mu, sigma, 10000)

print("Среднее значение : ", np.mean(x_n))

print("Дисперсия : ", np.var(x_n))

print("Коэффициент асимметрии : ", skew(x_n)) 

print("Коэффициент эксцесса : ", kurtosis(x_n))

print("Размер выборки = 100000")
x_n = np.random.normal(mu, sigma, 100000)

print("Среднее значение : ", np.mean(x_n))

print("Дисперсия : ", np.var(x_n))

print("Коэффициент асимметрии : ", skew(x_n)) 

print("Коэффициент эксцесса : ", kurtosis(x_n))

plt.figure(figsize=(10, 5.5))
count, bins, ignored = plt.hist(x_n, 30, edgecolor='k', density = True)

plt.figure(figsize=(10, 5.5))
plt.plot(bins, 1/(sigma * np.sqrt(2*np.pi)) * np.exp(- (bins - mu)**2 / (2 * sigma**2)), linewidth=2, color='r')
plt.show()

plt.figure(figsize=(10, 5.5))
count, bins, ignored = plt.hist(x_n, 30, edgecolor='k', density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2*np.pi)) * np.exp(- (bins - mu)**2 / (2 * sigma**2)), linewidth=2, color='r')
plt.show()
# Out:
# Размер выборки = 1000
# Среднее значение :  -0.01866665668533887
# Дисперсия :  1.0269457661136834
# Коэффициент асимметрии :  -0.10909652464302322
# Коэффициент эксцесса :  -0.10744290656471911
# Размер выборки = 10000
# Среднее значение :  -0.01097065375467106
# Дисперсия :  1.0054252917154365
# Коэффициент асимметрии :  0.021688053938689715
# Коэффициент эксцесса :  -0.012968159916912914
# Размер выборки = 100000
# Среднее значение :  -0.002940245775277916
# Дисперсия :  1.0048384404737851
# Коэффициент асимметрии :  0.012123868951958001
# Коэффициент эксцесса :  0.01251609858767333

# %%
print("Размер выборки = 1000")
x_r = np.random.rayleigh(1, 1000)
print("Среднее значение : ", np.mean(x_r))
print("Дисперсия : ", np.var(x_r))
print("Коэффициент асимметрии : ", skew(x_r)) 
print("Коэффициент эксцесса : ", kurtosis(x_r))

print("Размер выборки = 10000")
x_r = np.random.rayleigh(1, 10000)
print("Среднее значение : ", np.mean(x_r))
print("Дисперсия : ", np.var(x_r))
print("Коэффициент асимметрии : ", skew(x_r)) 
print("Коэффициент эксцесса : ", kurtosis(x_r))

print("Размер выборки = 100000")
x_r = np.random.rayleigh(1, 100000)
print("Среднее значение : ", np.mean(x_r))
print("Дисперсия : ", np.var(x_r))
print("Коэффициент асимметрии : ", skew(x_r)) 
print("Коэффициент эксцесса : ", kurtosis(x_r))

x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)

r = np.sqrt(pow(x, 2) + pow(y, 2))

plt.figure(figsize=(10, 5.5))
plt.hist(r,edgecolor='k')

plt.figure(figsize=(10, 5.5))
count, bins, ignored = plt.hist(x_r, 20, edgecolor='k', density=True)
# Out:
# Размер выборки = 1000
# Среднее значение :  1.2824740310520684
# Дисперсия :  0.4430289552128849
# Коэффициент асимметрии :  0.738226143861256
# Коэффициент эксцесса :  0.6413196143451887
# Размер выборки = 10000
# Среднее значение :  1.2597760220568175
# Дисперсия :  0.43255141640132705
# Коэффициент асимметрии :  0.6497530609163207
# Коэффициент эксцесса :  0.2857638205912507
# Размер выборки = 100000
# Среднее значение :  1.2539236148055857
# Дисперсия :  0.42739221335629407
# Коэффициент асимметрии :  0.6286594636782166
# Коэффициент эксцесса :  0.23799558212726746

# %%
print("Размер выборки = 1000")
x_p = np.random.poisson(1, 1000)

print("Среднее значение : ", np.mean(x_p))

print("Дисперсия : ", np.var(x_p))

print("Коэффициент асимметрии : ", skew(x_p)) 

print("Коэффициент эксцесса : ", kurtosis(x_p))

print("Размер выборки = 10000")
x_p = np.random.poisson(1, 10000)

print("Среднее значение : ", np.mean(x_p))

print("Дисперсия : ", np.var(x_p))

print("Коэффициент асимметрии : ", skew(x_p)) 

print("Коэффициент эксцесса : ", kurtosis(x_p))

print("Размер выборки = 100000")
x_p = np.random.poisson(1, 100000)

print("Среднее значение : ", np.mean(x_p))

print("Дисперсия : ", np.var(x_p))

print("Коэффициент асимметрии : ", skew(x_p)) 

print("Коэффициент эксцесса : ", kurtosis(x_p))

plt.figure(figsize=(10, 5.5))

count, bins, ignored = plt.hist(x_p, 20, edgecolor='k', density=True)
# Out:
# Размер выборки = 1000
# Среднее значение :  0.992
# Дисперсия :  1.027936
# Коэффициент асимметрии :  1.1040838181309034
# Коэффициент эксцесса :  1.789111957224538
# Размер выборки = 10000
# Среднее значение :  1.0002
# Дисперсия :  1.00019996
# Коэффициент асимметрии :  1.0090971962730502
# Коэффициент эксцесса :  1.0133870458293535
# Размер выборки = 100000
# Среднее значение :  0.99781
# Дисперсия :  0.9967652039
# Коэффициент асимметрии :  0.9985399472330895
# Коэффициент эксцесса :  0.962278985889816

# %%
u1 = np.random.uniform(0, 1, 100000)

u2 = np.random.uniform(0, 1, 100000)

z0 = np.sqrt(-2 * np.log(u1)) * np.cos(2 * np.pi*u2);
z1 = np.sqrt(-2 * np.log(u1)) * np.sin(2 * np.pi*u2);

z = z0 * 1 + 0

plt.figure(figsize=(10, 5.5))
plt.hist(u1,edgecolor='k')

plt.figure(figsize=(10, 5.5))
plt.hist(u2,edgecolor='k')

plt.figure(figsize=(10, 5.5))
plt.hist(z,edgecolor='k')
# Out:
# (array([   33.,   430.,  3394., 13549., 28436., 30608., 17487.,  5180.,
#           811.,    72.]),
#  array([-4.26917689, -3.4377671 , -2.60635732, -1.77494754, -0.94353775,
#         -0.11212797,  0.71928182,  1.5506916 ,  2.38210139,  3.21351117,
#          4.04492096]),
#  <BarContainer object of 10 artists>)

# %%
m = pow(2, 31) - 1;
a = 16807;
c = 1;
seed = 12345;
x_u = np.zeros(1000)
x_u[0] = ((seed * a + 1) % m) / m
for i in range(1, 1000):
     x_u[i] = ((a * x_u[i - 1] + c) % m)

plt.figure(figsize=(10, 5.5))  
count, bins, ignored = plt.hist(x_u, 30, edgecolor='k', density = True)

x_u = list(map(lambda x: (1-0)*(x/m)+0,x_u))
plt.figure(figsize=(10, 5.5))  
count, bins, ignored = plt.hist(x_u, 30, edgecolor='k', density = True)
